# %%
import pandas as pd
import numpy

# %%
corr_file = "world_corruption_DataW.csv"
corr_file_df = pd.read_csv(corr_file)
#corr_file_df.head()
## brings file in

# %%
is_corr = corr_file_df[corr_file_df['Indicator Name'].str.contains('Corruption: Estimate')]
is_corr.head()
#is_corr_df = pd.corr_file_df[(corr_file_df['Indicator Name'].str.contains('Corruption: Estimate')]
#print (is_corr_df)
# Out:
#        Country Name Country Code                   Indicator Name  \
# 0       Afghanistan          AFG  Control of Corruption: Estimate
# 36          Albania          ALB  Control of Corruption: Estimate
# 72          Algeria          DZA  Control of Corruption: Estimate
# 108  American Samoa          ASM  Control of Corruption: Estimate
# 144         Andorra          ADO  Control of Corruption: Estimate
#
#     Indicator Code      1996      1998      2000      2002      2003  \
# 0           CC.EST -1.846840 -1.836265 -1.913773 -1.426400 -1.546852
# 36          CC.EST -1.090980 -1.008591 -0.824482 -0.856775 -0.768750
# 72          CC.EST -0.479991 -0.969703 -0.948723 -0.936570 -0.668101
# 108         CC.EST       NaN       NaN       NaN       NaN       NaN
# 144         CC.EST  1.359539  1.380149  1.384883  1.299334  1.316520
#
#          2004      2005      2006      2007      2008      2009      2010  \
# 0   -1.424300 -1.464257 -1.444516 -1.590514 -1.637169 -1.513279 -1.624466
# ...

# %%
corr_names = is_corr[['Country Name']].copy()
corr_names.head()
#corr_ccode = is_corr[['Country Code']].copy()
# Out:
#        Country Name
# 0       Afghanistan
# 36          Albania
# 72          Algeria
# 108  American Samoa
# 144         Andorra

# %%
# one method #corr_names.assign(Inlist='Yes') #corr_names.head()
#this just added it
corr_names['Inlist']="Yes"
corr_names.head()
# Out:
#        Country Name Inlist
# 0       Afghanistan    Yes
# 36          Albania    Yes
# 72          Algeria    Yes
# 108  American Samoa    Yes
# 144         Andorra    Yes

# %%
popu_file = "world_population_WB.csv"
popu_file_df = pd.read_csv(popu_file)
popu_file_df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2009  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101455.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  28394813.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  22514281.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2927519.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     84463.0
#
#          2010        2011        2012        2013        2014        2015  \
# ...

# %%
popu_names = popu_file_df[['Country Name']].copy()
popu_names.head()
# Out:
#   Country Name
# 0        Aruba
# 1  Afghanistan
# 2       Angola
# 3      Albania
# 4      Andorra

# %%
popu_names['InPopu']="Yes"
popu_names.head()
# Out:
#   Country Name InPopu
# 0        Aruba    Yes
# 1  Afghanistan    Yes
# 2       Angola    Yes
# 3      Albania    Yes
# 4      Andorra    Yes

# %%
# pd.merge(corr_names, popu_names, on='Country Name', how='outer')
dict_df = pd.merge(corr_names, popu_names, on='Country Name', how='outer')
#dict_df.head()
cp_left_df = pd.merge(corr_names, popu_names, on='Country Name', how='left')
#cp_left_df.head()
cp_right_df = pd.merge(corr_names, popu_names, on='Country Name', how='right')
cp_right_df.head()
# Out:
#      Country Name Inlist InPopu
# 0     Afghanistan    Yes    Yes
# 1         Albania    Yes    Yes
# 2         Algeria    Yes    Yes
# 3  American Samoa    Yes    Yes
# 4         Andorra    Yes    Yes

# %%
Corr_noPop = cp_left_df[cp_left_df['InPopu'].isnull()]
Corr_noPop
# Out:
#                 Country Name Inlist InPopu
# 6                   Anguilla    Yes    NaN
# 45              Cook Islands    Yes    NaN
# 66             French Guiana    Yes    NaN
# 94   Jersey, Channel Islands    Yes    NaN
# 99          Korea, Dem. Rep.    Yes    NaN
# 114           Macedonia, FYR    Yes    NaN
# 122               Martinique    Yes    NaN
# 138     Netherlands Antilles    Yes    NaN
# 144                     Niue    Yes    NaN
# 158                  Reunion    Yes    NaN
# 184                Swaziland    Yes    NaN
# 188            Taiwan, China    Yes    NaN

# %%
Popu_NoCor = cp_right_df[cp_right_df['Inlist'].isnull()]
Popu_NoCor.head()
# Out:
#                        Country Name Inlist InPopu
# 203                      Arab World    NaN    Yes
# 204  Central Europe and the Baltics    NaN    Yes
# 205                 Channel Islands    NaN    Yes
# 206          Caribbean small states    NaN    Yes
# 207                         Curacao    NaN    Yes

# %%
Popu_NoCor[Popu_NoCor["Country Name"].str.startswith("C")]
# Out:
#                        Country Name Inlist InPopu
# 204  Central Europe and the Baltics    NaN    Yes
# 205                 Channel Islands    NaN    Yes
# 206          Caribbean small states    NaN    Yes
# 207                         Curacao    NaN    Yes

# %%
di = {'Korea, Rep.': 'Korea, Dem. Rep.', 'North Macedonia' : 'Macedonia, FYR', 
        "China, People's Republic of" : 'China', 'Congo, Dem. Rep. of the' : 'Congo, Dem. Rep.', 
        'Congo, Republic of ' : 'Congo, Rep.', 'Egypt' : 'Egypt, Arab Rep.', 
        'Hong Kong SAR' : 'Hong Kong SAR, China', 'Iran' : 'Iran, Islamic Rep.', 
        'Korea, Republic of' : 'Korea, Dem. Rep.', 'Lao P.D.R.' : 'Lao PDR', 
        'Macao SAR' : 'Macao SAR, China', 'Micronesia, Fed. States of' : 'Micronesia, Fed. Sts.', 
        'Netherlands' : 'Netherlands Antilles', 'South Sudan, Republic of' : 'South Sudan', 
        'Taiwan Province of China' : 'Taiwan, China', 'Venezuela' : 'Venezuela, RB', 
        'Yemen' : 'Yemen, Rep.'}

# %%
popu_file_df.replace({'Country Name': di})
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
#NotInPop = dict_df[dict_df[.index.tolist()
#NotInPop
#NonInPop = dict_df[dict_df['InPopu'].isnull()]
#NotInPop.head()
#x = dict_df[(dict_df['InPopu'].isnull)

# %%
#import sys  
#reload(sys)  
#sys.setdefaultencoding('utf8')
#pd.read_csv('ml-100k/u.item', sep='|', names=m_cols , encoding='latin-1')
gdp_file = "world_GDP_imf.csv"
gdp_file_df = pd.read_csv(gdp_file)
gdp_file_df.head()
# Out:
#   GDP, current prices (Billions of U.S. dollars)     1980     1981     1982  \
# 0                                            NaN      NaN      NaN      NaN
# 1                                    Afghanistan  no data  no data  no data
# 2                                        Albania    1.946    2.229    2.296
# 3                                        Algeria   42.346   44.372    44.78
# 4                                         Angola    6.639    6.214    6.214
#
#       1983     1984     1985     1986     1987     1988  ...     2015  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN  ...      NaN
# 1  no data  no data  no data  no data  no data  no data  ...   20.057
# 2    2.319     2.29    2.339    2.587    2.566     2.53  ...   11.364
# 3   47.529   51.513   61.132   61.535     63.3   51.664  ...  165.979
# 4    6.476    6.864    8.457    7.918     9.05    9.818  ...  116.194
#
#       2016     2017     2018     2019     2020     2021     2022     2023  \
# ...

# %%
#df.rename(columns={ df.columns[1]: "your value" })
#gdp_file_df.rename(columns={ gdp_file_df.columns[0]: "Country Name" })
gdp_file_df.rename(columns={'GDP, current prices (Billions of U.S. dollars)':'Country Name'}, inplace=True)
gdp_file_df.head()
# Out:
#   Country Name     1980     1981     1982     1983     1984     1985     1986  \
# 0          NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1  Afghanistan  no data  no data  no data  no data  no data  no data  no data
# 2      Albania    1.946    2.229    2.296    2.319     2.29    2.339    2.587
# 3      Algeria   42.346   44.372    44.78   47.529   51.513   61.132   61.535
# 4       Angola    6.639    6.214    6.214    6.476    6.864    8.457    7.918
#
#       1987     1988  ...     2015     2016     2017     2018     2019  \
# 0      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 1  no data  no data  ...   20.057   19.428   20.235   19.585    19.99
# 2    2.566     2.53  ...   11.364   11.868   13.055   15.202    15.96
# 3     63.3   51.664  ...  165.979   160.13  167.555  180.441  183.687
# 4     9.05    9.818  ...  116.194  101.124  122.124  107.316   92.191
#
#       2020     2021     2022     2023     2024
# ...

# %%
gdp_names = gdp_file_df[['Country Name']].copy()
#popu_names.head()
gdp_names['InGDP']="Yes"
gdp_names.head()
# Out:
#   Country Name InGDP
# 0          NaN   Yes
# 1  Afghanistan   Yes
# 2      Albania   Yes
# 3      Algeria   Yes
# 4       Angola   Yes

# %%
gdp_file_df.replace({'Country Name': di})
# Out:
#                                           Country Name       1980       1981  \
# 0                                                  NaN        NaN        NaN
# 1                                          Afghanistan    no data    no data
# 2                                              Albania      1.946      2.229
# 3                                              Algeria     42.346     44.372
# 4                                               Angola      6.639      6.214
# 5                                  Antigua and Barbuda      0.131      0.148
# 6                                            Argentina    226.569    184.014
# 7                                              Armenia    no data    no data
# 8                                                Aruba    no data    no data
# 9                                            Australia    162.618    188.056
# 10                                             Austria     80.923     70.122
# ...

# %%
#dict_df = pd.merge(dict_df, gdp_names, on='Country Name', how='outer')
#pd.merge(dict_df, gdp_names, on='Country Name', how='outer')
#dict_df.head(20)

# %%
Combined_df = pd.merge(is_corr[['Country Name','Indicator Name','2014']], popu_file_df[['Country Name','Indicator Name','2014']], on='Country Name', how='left')
#cp_left_df.head()

# %%
Combined_df = pd.merge(Combined_df, gdp_file_df[['Country Name','2014']], on='Country Name', how='left')
#cp_left_df.head()

# %%
Combined_df.head()
# Out:
#      Country Name                 Indicator Name_x    2014_x  \
# 0     Afghanistan  Control of Corruption: Estimate -1.331163
# 1         Albania  Control of Corruption: Estimate -0.552890
# 2         Algeria  Control of Corruption: Estimate -0.614451
# 3  American Samoa  Control of Corruption: Estimate  1.251688
# 4         Andorra  Control of Corruption: Estimate  1.251688
#
#     Indicator Name_y      2014_y    2014
# 0  Population, total  33370794.0  20.616
# 1  Population, total   2889104.0  13.219
# 2  Population, total  38923687.0  213.81
# 3  Population, total     55791.0     NaN
# 4  Population, total     79213.0     NaN
